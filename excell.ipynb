# %%
#file sales_data.csv is saved in file section <-

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/sales_data.csv')
data.describe()
# Out:
#              price    quantity      revenue
# count   349.000000  347.000000   352.000000
# mean    211.203438   14.394813  2030.511364
# std     228.378181    8.486458  1900.508335
# min      20.000000    3.000000   300.000000
# 25%      50.000000    8.000000   750.000000
# 50%     100.000000   12.000000  1200.000000
# 75%     200.000000   20.000000  2287.500000
# max    1200.000000   50.000000  7200.000000

# %%
data.head(10)
# Out:
#          date     product     category   price  quantity  revenue
# 0  2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1  2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 2  2022-01-02     T-Shirt     Clothing    20.0      50.0   1000.0
# 3  2022-01-03  Headphones  Electronics   100.0      20.0   2000.0
# 4  2022-01-04     T-Shirt     Clothing    20.0      25.0    500.0
# 5  2022-01-05       Watch  Accessories   150.0      10.0   1500.0
# 6  2022-01-06  Smartphone  Electronics   600.0       8.0   4800.0
# 7  2022-01-06      Tablet  Electronics   400.0       5.0   2000.0
# 8  2022-01-07        Coat     Clothing   100.0      10.0   1000.0
# 9  2022-01-08  Smartwatch  Accessories   200.0      12.0   2400.0

# %%
data.tail(10)
# Out:
#            date     product     category  price  quantity  revenue
# 359  2022-12-22    Sneakers      Shoeses   80.0      12.0    960.0
# 360  2022-12-23     T-Shirt     Clothing   20.0      25.0    500.0
# 361  2022-12-24  Smartwatch  Accessories  200.0       8.0   1600.0
# 362  2022-12-25       Jeans     Clothing   50.0      15.0    750.0
# 363  2022-12-26  Smartphone  Electronics  600.0       9.0   5400.0
# 364  2022-12-27       Watch  Accessories  150.0       5.0    750.0
# 365  2022-12-28        Coat     Clothing  100.0       5.0    500.0
# 366  2022-12-29  Headphones  Electronics  100.0      10.0   1000.0
# 367  2022-12-30  Smartphone  Electronics  600.0      11.0   6600.0
# 368  2022-12-31      Hoodie     Clothing   40.0      30.0   1200.0

# %%
print(data.dtypes)
# Out:
# date         object
# product      object
# category     object
# price       float64
# quantity    float64
# revenue     float64
# dtype: object

# %%
data['date'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 364    False
# 365    False
# 366    False
# 367    False
# 368    False
# Name: date, Length: 369, dtype: bool

# %%
data['date'].isnull().sum()
# Out:
# np.int64(0)

# %%
data.iloc[10:15]
# Out:
#           date     product     category  price  quantity  revenue
# 10  2022-01-09     Speaker  Electronics   80.0      15.0   1200.0
# 11  2022-01-10    Backpack         Bags   50.0      20.0   1000.0
# 12  2022-01-11      Hoodie     Clothing   40.0      30.0   1200.0
# 13  2022-01-12  Smartphone  Electronics  600.0      12.0   7200.0
# 14  2022-01-13    Sneakers        Shoes   80.0      10.0    800.0

# %%
data.loc[10:15]
# Out:
#           date     product     category  price  quantity  revenue
# 10  2022-01-09     Speaker  Electronics   80.0      15.0   1200.0
# 11  2022-01-10    Backpack         Bags   50.0      20.0   1000.0
# 12  2022-01-11      Hoodie     Clothing   40.0      30.0   1200.0
# 13  2022-01-12  Smartphone  Electronics  600.0      12.0   7200.0
# 14  2022-01-13    Sneakers        Shoes   80.0      10.0    800.0
# 15  2022-01-14      Wallet  Accessories   30.0      40.0   1200.0

# %%
data[data['price']>100]
# Out:
#            date     product     category   price  quantity  revenue
# 0    2022-01-01  Smartphone  Electronics   600.0      10.0   6000.0
# 1    2022-01-01      Laptop  Electronics  1200.0       5.0   6000.0
# 5    2022-01-05       Watch  Accessories   150.0      10.0   1500.0
# 6    2022-01-06  Smartphone  Electronics   600.0       8.0   4800.0
# 7    2022-01-06      Tablet  Electronics   400.0       5.0   2000.0
# ..          ...         ...          ...     ...       ...      ...
# 358  2022-12-21  Smartphone  Electronics   600.0       7.0   4200.0
# 361  2022-12-24  Smartwatch  Accessories   200.0       8.0   1600.0
# 363  2022-12-26  Smartphone  Electronics   600.0       9.0   5400.0
# 364  2022-12-27       Watch  Accessories   150.0       5.0    750.0
# 367  2022-12-30  Smartphone  Electronics   600.0      11.0   6600.0
#
# [140 rows x 6 columns]

# %%
data[data['price']>100][['product','category','price']]
# Out:
#         product     category   price
# 0    Smartphone  Electronics   600.0
# 1        Laptop  Electronics  1200.0
# 5         Watch  Accessories   150.0
# 6    Smartphone  Electronics   600.0
# 7        Tablet  Electronics   400.0
# ..          ...          ...     ...
# 358  Smartphone  Electronics   600.0
# 361  Smartwatch  Accessories   200.0
# 363  Smartphone  Electronics   600.0
# 364       Watch  Accessories   150.0
# 367  Smartphone  Electronics   600.0
#
# [140 rows x 3 columns]

# %%
data['price'].plot(kind='box',vert=False)
# Out:
# <Axes: >
