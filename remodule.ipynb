# %%
import re
pattern = 'ac..ve'
test_string = 'my activestate platform account is now active'
result = re.findall(pattern,test_string)
print(result)
# Out:
# ['active', 'active']

# %%
import re
text="""Text analysis with Python involves processing
and interpreting textual data to extract
insights, patterns, and meaning.
It is very intersting and we are having class upto 24x7.
 And to learn the topic , we require the basic knowledge of PYHTON."""
x=re.findall("[a-b]",text)
print(x)
# Out:
# ['a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'b', 'a']

# %%
x=re.findall("[A-Z]",text)
print(x)
# Out:
# ['T', 'P', 'I', 'A', 'P', 'Y', 'H', 'T', 'O', 'N']

# %%
x=re.findall("[A-Z 0-9]",text)
print(x)
# Out:
# ['T', ' ', ' ', ' ', 'P', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'I', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '2', '4', '7', ' ', 'A', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', 'P', 'Y', 'H', 'T', 'O', 'N']

# %%
x=re.findall("[A-Z0-9]",text)
print(x)
# Out:
# ['T', 'P', 'I', '2', '4', '7', 'A', 'P', 'Y', 'H', 'T', 'O', 'N']

# %%
 x=re.findall(r"\b\w*n\b",text)
 print(x)
 #here b is used for boundary that ends with n
# Out:
# ['Python', 'learn']

# %%
 x=re.findall(r"\b\w*[nN]\b",text)
 print(x)
# Out:
# ['Python', 'learn', 'PYHTON']

# %%
 x=re.findall(r"\ba\w*s\b",text)
 print(x)
 #here start with a
# Out:
# ['analysis']

# %%
 x=re.findall(r"\ba\w*y\w*s\b",text)
 print(x)
# Out:
# ['analysis']

# %%
 x=re.findall(r"\b[A-Za-z]{6}\b",text)
 print(x)
 #for length of 6
# Out:
# ['Python', 'having', 'PYHTON']

# %%
text="""Python is a versatile and beginner-friendly programming language
known for its clear syntax.
It supports multiple programming paradigms, including object-oriented,
procedural, and functional programming.
Widely used in web development, data science, automation, and artificial
intelligence, Python has a large and active community."""

# %%
import re
x=re.findall("[a-b|P]",text,re.IGNORECASE)
print(x)
# Out:
# ['P', 'a', 'a', 'a', 'b', 'p', 'a', 'a', 'a', 'a', 'a', 'p', 'p', 'p', 'p', 'a', 'p', 'a', 'a', 'b', 'p', 'a', 'a', 'a', 'p', 'a', 'b', 'p', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'P', 'a', 'a', 'a', 'a', 'a']

# %%
text='12345678909988889900999978698689698595875887 888888888'
re.findall(r"\b\d{9}\b",text)
# Out:
# ['888888888']

# %%
text="Python uses syntax"
re.findall(r'\b[A-Za-z]{3}\b',text)
# Out:
# []

# %%
re.findall(r'\bP\w*n\b',text)
# Out:
# ['Python']

# %%
text="""Python is a versatile and beginner-friendly programming language
known for its clear syntax.
It supports multiple programming paradigms, including object-oriented,
procedural, and functional programming.
Widely used in web development, data science, automation, and artificial
intelligence, Python has a large and active community."""

# %%
sentences = text.split(".")
print(sentences)
# Out:
# ['Python is a versatile and beginner-friendly programming language \nknown for its clear syntax', '   \nIt supports multiple programming paradigms, including object-oriented, \nprocedural, and functional programming', '  \nWidely used in web development, data science, automation, and artificial \nintelligence, Python has a large and active community', '']

# %%
sentences = text.split(".")
cleaned = []
for s in sentences:
  s = s.strip()
if s:
  cleaned.append(s)
print(cleaned)
# Out:
# []

# %%
text="""Python is amazing! Did you know it was created by Guido van Rossum
in 1991?
It’s used for web development, data science, and AI.
Can you believe Instagram and YouTube use Python? Incredible, right!  Many
developers love its simplicity. But is Python always the best choice? Not
necessarily.
Still, it’s one of the most popular languages today!"""
sentences = text.split(".")
cleaned =[]
for s in sentences:
  s = s.strip()
if s:
  cleaned.append(s)
print(cleaned)
# Out:
# ['Still, it’s one of the most popular languages today!']

# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import sent_tokenize
sentences = sent_tokenize(text)
print(sentences)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Python is amazing!', 'Did you know it was created by Guido van Rossum \nin 1991?', 'It’s used for web development, data science, and AI.', 'Can you believe Instagram and YouTube use Python?', 'Incredible, right!', 'Many \ndevelopers love its simplicity.', 'But is Python always the best choice?', 'Not \nnecessarily.', 'Still, it’s one of the most popular languages today!']

# %%
from nltk.tokenize import word_tokenize
text = "Python is easy to learn. It is also powerful!"
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Python', 'is', 'easy', 'to', 'learn', '.', 'It', 'is', 'also', 'powerful', '!']

# %%
word_count = len(tokens)
print(word_count)
# Out:
# 11

# %%
lowered = [w.lower() for w in tokens]
print(lowered)
# Out:
# ['python', 'is', 'easy', 'to', 'learn', '.', 'it', 'is', 'also', 'powerful', '!']

# %%
stop_words = {"am", "i", "of",'but','do','at','all'}
text = "I am fond of Python,but i do not like Java at all."
words = re.findall(r"\b\w+\b", text.lower())
stop_words_text = [w for w in words if w in stop_words]
non_stop_in_text = [w for w in words if w not in stop_words]
print("Stop words in text:", stop_words_text)
print("Stop words in text:", non_stop_in_text)
# Out:
# Stop words in text: ['i', 'am', 'of', 'but', 'i', 'do', 'at', 'all']
# Stop words in text: ['fond', 'python', 'not', 'like', 'java']

# %%
#removing nltk stop
from nltk.corpus import stopwords
nltk.download('stopwords')
text="""Natural Language Processing (NLP) is a branch of Artificial Intelligence.
It deals with the interaction between computers and humans using natural
language.  Text Analysis helps extract meaningful insights from text data.
Applications of NLP include chatbots, sentiment analysis, and machine
translation."""
tokens = word_tokenize(text)
stop_words = set(stopwords.words('english'))
filtered = [w for w in tokens if w.lower() not in stop_words]
print("Original tokens:", tokens)
print("After removing stop words:", filtered)
# Out:
# Original tokens: ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'is', 'a', 'branch', 'of', 'Artificial', 'Intelligence', '.', 'It', 'deals', 'with', 'the', 'interaction', 'between', 'computers', 'and', 'humans', 'using', 'natural', 'language', '.', 'Text', 'Analysis', 'helps', 'extract', 'meaningful', 'insights', 'from', 'text', 'data', '.', 'Applications', 'of', 'NLP', 'include', 'chatbots', ',', 'sentiment', 'analysis', ',', 'and', 'machine', 'translation', '.']
# After removing stop words: ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'branch', 'Artificial', 'Intelligence', '.', 'deals', 'interaction', 'computers', 'humans', 'using', 'natural', 'language', '.', 'Text', 'Analysis', 'helps', 'extract', 'meaningful', 'insights', 'text', 'data', '.', 'Applications', 'NLP', 'include', 'chatbots', ',', 'sentiment', 'analysis', ',', 'machine', 'translation', '.']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# ...

# %%
import re
words = re.findall(r'\b\w+\b', text) # only words
word_count = len(words)
print("Total words:", word_count)
# Out:
# Total words: 41

# %%
word_freq = {}
for w in words:
  if w in word_freq:
    word_freq[w] += 1
  else:
    word_freq[w] = 1
print(word_freq)
# Out:
# {'Natural': 1, 'Language': 1, 'Processing': 1, 'NLP': 2, 'is': 1, 'a': 1, 'branch': 1, 'of': 2, 'Artificial': 1, 'Intelligence': 1, 'It': 1, 'deals': 1, 'with': 1, 'the': 1, 'interaction': 1, 'between': 1, 'computers': 1, 'and': 2, 'humans': 1, 'using': 1, 'natural': 1, 'language': 1, 'Text': 1, 'Analysis': 1, 'helps': 1, 'extract': 1, 'meaningful': 1, 'insights': 1, 'from': 1, 'text': 1, 'data': 1, 'Applications': 1, 'include': 1, 'chatbots': 1, 'sentiment': 1, 'analysis': 1, 'machine': 1, 'translation': 1}
